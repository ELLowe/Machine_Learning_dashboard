# %%
# Dependencies
from sklearn import tree
import pandas as pd
import os 
from sklearn.model_selection import train_test_split

# %%
# Load in data
df = pd.read_csv('../cleaned_data/cleaned_disorder.csv')
df.head()
# Out:
#    Unnamed: 0  Sex  Race  Age  Number of Bio. Parents  Number of Siblings  \
# 0           0    1     0    2                       1                   1
# 1           1    0     1    2                       0                   3
# 2           2    1     1    3                       2                   1
# 3           3    1     0    4                       2                   0
# 4           4    1     0    5                       2                   3
#
#    Poverty Status  Social Phobia  ADHD  CD  ...  Number of Type A Stressors  \
# 0               0              1     0   0  ...                           1
# 1               1              0     1   0  ...                           3
# 2               0              0     0   0  ...                           1
# 3               0              0     0   0  ...                           2
# 4               0              1     0   1  ...                           3
#
#    Number of Type B Stressors  Frequency Temper Tantrums  \
# 0                           1                         27
# 1                           2                        282
# 2                           0                          3
# 3                           0                         30
# 4                           8                        637
#
#    Frequency Irritable Mood  Number of Sleep Disturbances  \
# 0                       396                             4
# 1                      1179                             6
# 2                         0                             9
# 3                        45                             6
# 4                      1170                            10
#
#    Number of Physical Symptoms  Number of Sensory Sensitivities  \
# 0                            3                                2
# 1                            1                                0
# 2                            4                                1
# 3                            0                                0
# 4                            5                                2
#
#    Family History - Substance Abuse  Family History - Psychiatric Diagnosis  \
# 0                                 0                                       0
# 1                                 1                                       1
# 2                                 0                                       0
# 3                                 0                                       1
# 4                                 0                                       0
#
#    disorder
# 0       GAD
# 1      None
# 2       SAD
# 3      None
# 4      Both
#
# [5 rows x 23 columns]

# %%
# drop carried over index
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#    Sex  Race  Age  Number of Bio. Parents  Number of Siblings  Poverty Status  \
# 0    1     0    2                       1                   1               0
# 1    0     1    2                       0                   3               1
# 2    1     1    3                       2                   1               0
# 3    1     0    4                       2                   0               0
# 4    1     0    5                       2                   3               0
#
#    Social Phobia  ADHD  CD  Depression  ...  Number of Type A Stressors  \
# 0              1     0   0           1  ...                           1
# 1              0     1   0           0  ...                           3
# 2              0     0   0           0  ...                           1
# 3              0     0   0           0  ...                           2
# 4              1     0   1           1  ...                           3
#
#    Number of Type B Stressors  Frequency Temper Tantrums  \
# 0                           1                         27
# 1                           2                        282
# 2                           0                          3
# 3                           0                         30
# 4                           8                        637
#
#    Frequency Irritable Mood  Number of Sleep Disturbances  \
# 0                       396                             4
# 1                      1179                             6
# 2                         0                             9
# 3                        45                             6
# 4                      1170                            10
#
#    Number of Physical Symptoms  Number of Sensory Sensitivities  \
# 0                            3                                2
# 1                            1                                0
# 2                            4                                1
# 3                            0                                0
# 4                            5                                2
#
#    Family History - Substance Abuse  Family History - Psychiatric Diagnosis  \
# 0                                 0                                       0
# 1                                 1                                       1
# 2                                 0                                       0
# 3                                 0                                       1
# 4                                 0                                       0
#
#    disorder
# 0       GAD
# 1      None
# 2       SAD
# 3      None
# 4      Both
#
# [5 rows x 22 columns]

# %%
# split data into inputs and outputs
data = df.values
inputs = data[:, 0:21]
outputs = data[:, 21]

# %%
# split data into inputs and outputs

outcomes = df['disorder']
outcomes.head()

input_factors = df.drop(['disorder'], axis = 1)
input_factors.head()
feature_names = input_factors.columns

# %%
# Train test groups
input_train, input_test, output_train, output_test = train_test_split(input_factors, outcomes, random_state=42)

# %%
# decision tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(input_train, output_train)
clf.score(input_test, output_test)
# Out:
# 0.6805555555555556

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
randomforest = RandomForestClassifier(n_estimators=200)
randomforest = randomforest.fit(input_train, output_train)
randomforest.score(input_test, output_test)
# Out:
# 0.7083333333333334

# %%
# Feature importance test
sorted(zip(randomforest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.11300577500777126, 'Number of Sleep Disturbances'),
#  (0.09789944488191049, 'Frequency Temper Tantrums'),
#  (0.09165424551794364, 'Number of Physical Symptoms'),
#  (0.08854679751548673, 'Frequency Irritable Mood'),
#  (0.07922271597501963, 'Number of Impairments'),
#  (0.07350097521795339, 'Number of Type B Stressors'),
#  (0.06373718024280844, 'Age'),
#  (0.055430769310811145, 'Number of Type A Stressors'),
#  (0.04310093503971255, 'Social Phobia'),
#  (0.042148974937337845, 'Number of Siblings'),
#  (0.03195655924023905, 'Number of Sensory Sensitivities'),
#  (0.029812294426749025, 'Race'),
#  (0.029790873027791587, 'Number of Bio. Parents'),
#  (0.028569933719714898, 'CD'),
#  (0.027543823706508656, 'Sex'),
#  (0.02673862985562419, 'Poverty Status'),
#  (0.020330180828023993, 'Family History - Substance Abuse'),
#  (0.020192999655557337, 'Family History - Psychiatric Diagnosis'),
#  (0.01629988034644706, 'ODD'),
#  (0.011423496442212388, 'ADHD'),
#  (0.009093515104376533, 'Depression')]
