# %%
# Dependencies
from sklearn import tree
import pandas as pd
import os 
from sklearn.model_selection import train_test_split

# %%
# Load in data
df = pd.read_csv('../cleaned_data/SAD_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0  Sex  Race  Age  Number of Bio. Parents  Number of Siblings  \
# 0           0    1     0    2                       1                   1
# 1           1    0     1    2                       0                   3
# 2           2    1     1    3                       2                   1
# 3           3    1     0    4                       2                   0
# 4           4    1     0    5                       2                   3
#
#    Poverty Status  SAD  Social Phobia  ADHD  ...  Number of Impairments  \
# 0               0    0              1     0  ...                      4
# 1               1    0              0     1  ...                      5
# 2               0    1              0     0  ...                      0
# 3               0    0              0     0  ...                      0
# 4               0    1              1     0  ...                      7
#
#    Number of Type A Stressors  Number of Type B Stressors  \
# 0                           1                           1
# 1                           3                           2
# 2                           1                           0
# 3                           2                           0
# 4                           3                           8
#
#    Frequency Temper Tantrums  Frequency Irritable Mood  \
# 0                         27                       396
# 1                        282                      1179
# 2                          3                         0
# 3                         30                        45
# 4                        637                      1170
#
#    Number of Sleep Disturbances  Number of Physical Symptoms  \
# 0                             4                            3
# 1                             6                            1
# 2                             9                            4
# 3                             6                            0
# 4                            10                            5
#
#    Number of Sensory Sensitivities  Family History - Substance Abuse  \
# 0                                2                                 0
# 1                                0                                 1
# 2                                1                                 0
# 3                                0                                 0
# 4                                2                                 0
#
#    Family History - Psychiatric Diagnosis
# 0                                       0
# 1                                       1
# 2                                       0
# 3                                       1
# 4                                       0
#
# [5 rows x 23 columns]

# %%
# Drop carried over index
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#    Sex  Race  Age  Number of Bio. Parents  Number of Siblings  Poverty Status  \
# 0    1     0    2                       1                   1               0
# 1    0     1    2                       0                   3               1
# 2    1     1    3                       2                   1               0
# 3    1     0    4                       2                   0               0
# 4    1     0    5                       2                   3               0
#
#    SAD  Social Phobia  ADHD  CD  ...  Number of Impairments  \
# 0    0              1     0   0  ...                      4
# 1    0              0     1   0  ...                      5
# 2    1              0     0   0  ...                      0
# 3    0              0     0   0  ...                      0
# 4    1              1     0   1  ...                      7
#
#    Number of Type A Stressors  Number of Type B Stressors  \
# 0                           1                           1
# 1                           3                           2
# 2                           1                           0
# 3                           2                           0
# 4                           3                           8
#
#    Frequency Temper Tantrums  Frequency Irritable Mood  \
# 0                         27                       396
# 1                        282                      1179
# 2                          3                         0
# 3                         30                        45
# 4                        637                      1170
#
#    Number of Sleep Disturbances  Number of Physical Symptoms  \
# 0                             4                            3
# 1                             6                            1
# 2                             9                            4
# 3                             6                            0
# 4                            10                            5
#
#    Number of Sensory Sensitivities  Family History - Substance Abuse  \
# 0                                2                                 0
# 1                                0                                 1
# 2                                1                                 0
# 3                                0                                 0
# 4                                2                                 0
#
#    Family History - Psychiatric Diagnosis
# 0                                       0
# 1                                       1
# 2                                       0
# 3                                       1
# 4                                       0
#
# [5 rows x 22 columns]

# %%
# split into input & output
data = df.values
inputs = data[:, 0:21]
outputs = data[:, 21]

# %%
# split into input & output
 
outcomes = df['SAD']
outcomes.head()

input_factors = df.drop(['SAD'], axis = 1)
input_factors.head()
feature_names = input_factors.columns

# %%
# Train test groups
input_train, input_test, output_train, output_test = train_test_split(input_factors, outcomes, random_state=42)

# %%
# decision tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(input_train, output_train)
clf.score(input_test, output_test)
# Out:
# 0.8472222222222222

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
randomforest = RandomForestClassifier(n_estimators=200)
randomforest = randomforest.fit(input_train, output_train)
randomforest.score(input_test, output_test)
# Out:
# 0.8472222222222222

# %%
# Feature importance test
sorted(zip(randomforest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.1270079234864939, 'Number of Sleep Disturbances'),
#  (0.10900898033302672, 'Number of Physical Symptoms'),
#  (0.09652229257267225, 'Frequency Temper Tantrums'),
#  (0.08524371738145062, 'Frequency Irritable Mood'),
#  (0.08197157896684706, 'Number of Type B Stressors'),
#  (0.062416772220748075, 'Social Phobia'),
#  (0.06115225199374337, 'Number of Impairments'),
#  (0.04873595970680877, 'Number of Siblings'),
#  (0.04856400338932716, 'Number of Type A Stressors'),
#  (0.048038976558714, 'Age'),
#  (0.03783579085787905, 'CD'),
#  (0.029471940951296974, 'Number of Sensory Sensitivities'),
#  (0.02538318559162597, 'Race'),
#  (0.0247876026130504, 'Family History - Substance Abuse'),
#  (0.02388609620621948, 'Poverty Status'),
#  (0.023826199023709745, 'Number of Bio. Parents'),
#  (0.018345823376236227, 'Family History - Psychiatric Diagnosis'),
#  (0.01643605824572865, 'Sex'),
#  (0.012805878117416403, 'ODD'),
#  (0.01018710399182004, 'Depression'),
#  (0.008371864415184954, 'ADHD')]
