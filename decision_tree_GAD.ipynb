# %%
# Dependencies
from sklearn import tree
import pandas as pd
import os 
from sklearn.model_selection import train_test_split

# %%
# Load in data
df = pd.read_csv('GAD_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0  Sex  Race  Age  Number of Bio. Parents  Number of Siblings  \
# 0           0    1     0    2                       1                   1
# 1           1    0     1    2                       0                   3
# 2           2    1     1    3                       2                   1
# 3           3    1     0    4                       2                   0
# 4           4    1     0    5                       2                   3
#
#    Poverty Status  GAD  Social Phobia  ADHD  ...  Number of Impairments  \
# 0               0    1              1     0  ...                      4
# 1               1    0              0     1  ...                      5
# 2               0    0              0     0  ...                      0
# 3               0    0              0     0  ...                      0
# 4               0    1              1     0  ...                      7
#
#    Number of Type A Stressors  Number of Type B Stressors  \
# 0                           1                           1
# 1                           3                           2
# 2                           1                           0
# 3                           2                           0
# 4                           3                           8
#
#    Frequency Temper Tantrums  Frequency Irritable Mood  \
# 0                         27                       396
# 1                        282                      1179
# 2                          3                         0
# 3                         30                        45
# 4                        637                      1170
#
#    Number of Sleep Disturbances  Number of Physical Symptoms  \
# 0                             4                            3
# 1                             6                            1
# 2                             9                            4
# 3                             6                            0
# 4                            10                            5
#
#    Number of Sensory Sensitivities  Family History - Substance Abuse  \
# 0                                2                                 0
# 1                                0                                 1
# 2                                1                                 0
# 3                                0                                 0
# 4                                2                                 0
#
#    Family History - Psychiatric Diagnosis
# 0                                       0
# 1                                       1
# 2                                       0
# 3                                       1
# 4                                       0
#
# [5 rows x 23 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#    Sex  Race  Age  Number of Bio. Parents  Number of Siblings  Poverty Status  \
# 0    1     0    2                       1                   1               0
# 1    0     1    2                       0                   3               1
# 2    1     1    3                       2                   1               0
# 3    1     0    4                       2                   0               0
# 4    1     0    5                       2                   3               0
#
#    GAD  Social Phobia  ADHD  CD  ...  Number of Impairments  \
# 0    1              1     0   0  ...                      4
# 1    0              0     1   0  ...                      5
# 2    0              0     0   0  ...                      0
# 3    0              0     0   0  ...                      0
# 4    1              1     0   1  ...                      7
#
#    Number of Type A Stressors  Number of Type B Stressors  \
# 0                           1                           1
# 1                           3                           2
# 2                           1                           0
# 3                           2                           0
# 4                           3                           8
#
#    Frequency Temper Tantrums  Frequency Irritable Mood  \
# 0                         27                       396
# 1                        282                      1179
# 2                          3                         0
# 3                         30                        45
# 4                        637                      1170
#
#    Number of Sleep Disturbances  Number of Physical Symptoms  \
# 0                             4                            3
# 1                             6                            1
# 2                             9                            4
# 3                             6                            0
# 4                            10                            5
#
#    Number of Sensory Sensitivities  Family History - Substance Abuse  \
# 0                                2                                 0
# 1                                0                                 1
# 2                                1                                 0
# 3                                0                                 0
# 4                                2                                 0
#
#    Family History - Psychiatric Diagnosis
# 0                                       0
# 1                                       1
# 2                                       0
# 3                                       1
# 4                                       0
#
# [5 rows x 22 columns]

# %%
data = df.values
inputs = data[:, 0:21]
outputs = data[:, 21]

# %%
outcomes = df['GAD']
outcomes.head()

input_factors = df.drop(['GAD'], axis = 1)
input_factors.head()
feature_names = input_factors.columns

# %%
# Train test groups
input_train, input_test, output_train, output_test = train_test_split(input_factors, outcomes, random_state=42)

# %%
# decision tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(input_train, output_train)
clf.score(input_test, output_test)
# Out:
# 0.7777777777777778

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
randomforest = RandomForestClassifier(n_estimators=200)
randomforest = randomforest.fit(input_train, output_train)
randomforest.score(input_test, output_test)
# Out:
# 0.8333333333333334

# %%
# inputs
sorted(zip(randomforest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.1355563080171306, 'Number of Sleep Disturbances'),
#  (0.11445146799274766, 'Frequency Irritable Mood'),
#  (0.10527785545291682, 'Frequency Temper Tantrums'),
#  (0.09557010130971541, 'Number of Impairments'),
#  (0.07507992410488151, 'Age'),
#  (0.07021318004627929, 'Number of Physical Symptoms'),
#  (0.06352232920217424, 'Number of Type B Stressors'),
#  (0.05609239072688631, 'Number of Type A Stressors'),
#  (0.040429143857242965, 'Number of Siblings'),
#  (0.032005019097722055, 'Number of Sensory Sensitivities'),
#  (0.028740797465697288, 'Number of Bio. Parents'),
#  (0.028219191357233452, 'Social Phobia'),
#  (0.025876415780746953, 'Sex'),
#  (0.0254258435150185, 'Race'),
#  (0.020972438909487478, 'Poverty Status'),
#  (0.019573700773041467, 'CD'),
#  (0.01806997824729561, 'Family History - Substance Abuse'),
#  (0.01722214867317092, 'Family History - Psychiatric Diagnosis'),
#  (0.016695057722792825, 'ODD'),
#  (0.00554435842585169, 'Depression'),
#  (0.005462349321966907, 'ADHD')]
