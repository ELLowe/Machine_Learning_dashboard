# %%
# Dependencies
from sklearn import tree
import pandas as pd
import os 
from sklearn.model_selection import train_test_split

# %%
# Load in data
df = pd.read_csv('cleaned_disorder.csv')
df.head()
# Out:
#    Unnamed: 0  Sex  Race  Age  Number of Bio. Parents  Number of Siblings  \
# 0           0    1     0    2                       1                   1
# 1           1    0     1    2                       0                   3
# 2           2    1     1    3                       2                   1
# 3           3    1     0    4                       2                   0
# 4           4    1     0    5                       2                   3
#
#    Poverty Status  Social Phobia  ADHD  CD  ...  Number of Type A Stressors  \
# 0               0              1     0   0  ...                           1
# 1               1              0     1   0  ...                           3
# 2               0              0     0   0  ...                           1
# 3               0              0     0   0  ...                           2
# 4               0              1     0   1  ...                           3
#
#    Number of Type B Stressors  Frequency Temper Tantrums  \
# 0                           1                         27
# 1                           2                        282
# 2                           0                          3
# 3                           0                         30
# 4                           8                        637
#
#    Frequency Irritable Mood  Number of Sleep Disturbances  \
# 0                       396                             4
# 1                      1179                             6
# 2                         0                             9
# 3                        45                             6
# 4                      1170                            10
#
#    Number of Physical Symptoms  Number of Sensory Sensitivities  \
# 0                            3                                2
# 1                            1                                0
# 2                            4                                1
# 3                            0                                0
# 4                            5                                2
#
#    Family History - Substance Abuse  Family History - Psychiatric Diagnosis  \
# 0                                 0                                       0
# 1                                 1                                       1
# 2                                 0                                       0
# 3                                 0                                       1
# 4                                 0                                       0
#
#    disorder
# 0       GAD
# 1      None
# 2       SAD
# 3      None
# 4      Both
#
# [5 rows x 23 columns]

# %%
# split into inputs and outputs
outcomes = df['disorder']
outcomes.head()

input_factors = df.drop(['disorder','Unnamed: 0'], axis = 1)
input_factors.head()
feature_names = input_factors.columns

# %%
# Train/test Split
input_train, input_test, output_train, output_test = train_test_split(input_factors, outcomes, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(input_train, output_train)
clf.score(input_test, output_test)
# Out:
# 0.6944444444444444

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
randomforest = RandomForestClassifier(n_estimators=200)
randomforest = randomforest.fit(input_train, output_train)
randomforest.score(input_test, output_test)
# Out:
# 0.7222222222222222

# %%
sorted(zip(randomforest.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.11826185051395179, 'Number of Sleep Disturbances'),
#  (0.09653751980871547, 'Frequency Irritable Mood'),
#  (0.08865840795879412, 'Frequency Temper Tantrums'),
#  (0.08650015238604217, 'Number of Physical Symptoms'),
#  (0.07659894007260803, 'Number of Type B Stressors'),
#  (0.07622615204535299, 'Number of Impairments'),
#  (0.06699454628479379, 'Age'),
#  (0.057581991361833465, 'Number of Type A Stressors'),
#  (0.04659318875940675, 'Number of Siblings'),
#  (0.043607884778580894, 'Social Phobia'),
#  (0.03425901400616947, 'Number of Sensory Sensitivities'),
#  (0.02816319158842043, 'Number of Bio. Parents'),
#  (0.02805335388116781, 'Race'),
#  (0.02674743658703668, 'Sex'),
#  (0.026651402869814076, 'CD'),
#  (0.023162408876070975, 'Poverty Status'),
#  (0.01989091003027295, 'Family History - Substance Abuse'),
#  (0.01929065675288382, 'Family History - Psychiatric Diagnosis'),
#  (0.018450945081431417, 'ODD'),
#  (0.009911783870507401, 'ADHD'),
#  (0.007858262486145663, 'Depression')]
